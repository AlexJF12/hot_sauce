# %% [markdown]
# # Serious Eats Scrape
# http://www.seriouseats.com/2017/02/kenjis-favorite-hot-sauces-chili-pepper.html

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
url = 'http://www.seriouseats.com/2017/02/kenjis-favorite-hot-sauces-chili-pepper.html'

page = requests.get(url)
print page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Get Name of each product reviewed
names = []
for i in soup.findAll('h3'):
    names.append(i.get_text().split(':')[1])

# %%
for i in soup.head.children:
    print i
# Out:
# <meta charset="utf-8"/>
#
#
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#
#
#  generated by chapp // braestar // proxy // support@seriouseats.com
#
#
# <title>The Food Lab's Top 30 Hot Sauces, in No Particular Order | Serious Eats</title>
#
#
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#
#
# <link href="http://www.seriouseats.com/2017/02/kenjis-favorite-hot-sauces-chili-pepper.html" rel="canonical"/>
#
#
# <meta content="summary_large_image" name="twitter:card"/>
#
#
# <meta content="@seriouseats" name="twitter:site"/>
#
#
# <meta content="The Food Lab's Top 30 Hot Sauces, in No Particular Order" property="og:title">
# <meta content="Naming a &quot;best&quot; hot sauce is an impossible task, so I won't even attempt to limit my hot sauce recommendations to a single bottle, or even to a top five or 10. Nope: These are 30 of my favorite hot sauces." name="description">
# ...

# %%
soup.findAll('p')
# Out:
# [<p class="label">Follow Us</p>,
#  <p><div class="se-pinit-image-container"><img alt="20170206-hot-sauces-kenji-lopez-alt.jpg" class="mt-image-none" data-pin-no-hover="true" data-src="http://www.seriouseats.com/images/2017/02/20170206-hot-sauces-kenji-lopez-alt.jpg" height="1125" src="http://static.seriouseats.com/1/braestar/live/img/placeholder-entry-image.png" style="" width="1500"/><div class="nav-share se-pinit">\n<a aria-hidden="true" class="social-pinterest icon-wrapper" data-event="pinterest" data-location="entry-image-pinit" target="_blank" title="Share on Pinterest"><span class="icon icon-social-pinterest"></span></a>\n</div></div></p>,
#  <p class="caption">[Photographs: J. Kenji L\xf3pez-Alt]</p>,
# ...
